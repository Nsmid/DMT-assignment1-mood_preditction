# %% [markdown]
# # Assignment 1 - Advanced

# %% [markdown]
# Task: Predict the average mood of the user on the next day based on the data we obtained from the user on the days before

# %% [markdown]
# ### Insert Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Get data

# %%
df_data = pd.read_csv('dataset_mood_smartphone.csv')

# %%
df_data
# Out:
#         Unnamed: 0       id                     time        variable   value
# 0                1  AS14.01  2014-02-26 13:00:00.000            mood   6.000
# 1                2  AS14.01  2014-02-26 15:00:00.000            mood   6.000
# 2                3  AS14.01  2014-02-26 18:00:00.000            mood   6.000
# 3                4  AS14.01  2014-02-26 21:00:00.000            mood   7.000
# 4                5  AS14.01  2014-02-27 09:00:00.000            mood   6.000
# ...            ...      ...                      ...             ...     ...
# 376907     2770399  AS14.30  2014-04-11 07:51:16.948  appCat.weather   8.032
# 376908     2772465  AS14.30  2014-04-19 11:00:32.747  appCat.weather   3.008
# 376909     2774026  AS14.30  2014-04-26 10:19:07.434  appCat.weather   7.026
# 376910     2774133  AS14.30  2014-04-27 00:44:48.450  appCat.weather  23.033
# 376911     2784435  AS14.32  2014-04-07 18:25:14.036  appCat.weather  22.431
#
# [376912 rows x 5 columns]

# %% [markdown]
# ### TASK 1: PRE-PROCESS THE DATASET

# %% [markdown]
# ### Explore data:

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376912 entries, 0 to 376911
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  376912 non-null  int64
#  1   id          376912 non-null  object
#  2   time        376912 non-null  object
#  3   variable    376912 non-null  object
#  4   value       376710 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 14.4+ MB

# %%
df_data.describe()
# Out:
#          Unnamed: 0          value
# count  3.769120e+05  376710.000000
# mean   4.501273e+05      40.665313
# std    5.411519e+05     273.726007
# min    1.000000e+00  -82798.871000
# 25%    9.422875e+04       2.025000
# 50%    2.274385e+05       7.029000
# 75%    5.160412e+05      29.356000
# max    1.427711e+07   33960.246000

# %% [markdown]
# ### Treatment of outliers and missing values:

# %% [markdown]
# ### Change dtype to datetime

# %%
df_data.time = pd.to_datetime(df_data.time, format='%Y-%m-%d %H:%M:%S.%f')
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376912 entries, 0 to 376911
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  376912 non-null  int64
#  1   id          376912 non-null  object
#  2   time        376912 non-null  datetime64[ns]
#  3   variable    376912 non-null  object
#  4   value       376710 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 14.4+ MB

# %%
#df_data.dropna(subset='mood',inplace=True)

# %%
test = pd.DataFrame(df_data.groupby([pd.Grouper(key='time', freq='5D'),'variable','id']).value.mean())

# %%
test_df = test.reset_index()
test_df
# Out:
#            time            variable       id       value
# 0    2014-02-17                call  AS14.01    1.000000
# 1    2014-02-17                call  AS14.02    1.000000
# 2    2014-02-17                call  AS14.03    1.000000
# 3    2014-02-17                call  AS14.05    1.000000
# 4    2014-02-17                call  AS14.06    1.000000
# ...         ...                 ...      ...         ...
# 4204 2014-06-07  circumplex.arousal  AS14.24   -1.333333
# 4205 2014-06-07  circumplex.valence  AS14.24    1.000000
# 4206 2014-06-07                mood  AS14.24    7.000000
# 4207 2014-06-07              screen  AS14.24  133.231520
# 4208 2014-06-07                 sms  AS14.24    1.000000
#
# [4209 rows x 4 columns]

# %%
#test_df.loc[(test_df['id'] == 'AS14.01')]
#test_df.loc[(test_df['id'] == 'AS14.01') & (test_df['variable'] == 'mood')]
test_df.loc[(test_df['time'] == '2014-06-07')& (test_df['variable'] == 'mood')]
# Out:
#            time variable       id  value
# 4206 2014-06-07     mood  AS14.24    7.0

# %%
table = test_df.pivot_table(index=['id','time'], columns = 'variable', values='value', aggfunc='first',fill_value=0)

# %%
pivot = table.reset_index()

# %%
pivot
# Out:
# variable       id       time  activity  appCat.builtin  appCat.communication  \
# 0         AS14.01 2014-02-17  0.000000        0.000000              0.000000
# 1         AS14.01 2014-02-22  0.000000        0.000000              0.000000
# 2         AS14.01 2014-02-27  0.000000        0.000000              0.000000
# 3         AS14.01 2014-03-04  0.000000        0.000000              0.000000
# 4         AS14.01 2014-03-09  0.000000        0.000000              0.000000
# ..            ...        ...       ...             ...                   ...
# 439       AS14.33 2014-05-08  0.043687       11.207859             42.483331
# 440       AS14.33 2014-05-13  0.061670       13.078407             61.265164
# 441       AS14.33 2014-05-18  0.014787       11.675640             65.116378
# 442       AS14.33 2014-05-23  0.059548       11.454054             41.483089
# 443       AS14.33 2014-05-28  0.153546       11.226798             42.107938
#
# ...

# %%
pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    444 non-null    object
#  1   time                  444 non-null    datetime64[ns]
#  2   activity              444 non-null    float64
#  3   appCat.builtin        444 non-null    float64
#  4   appCat.communication  444 non-null    float64
#  5   appCat.entertainment  444 non-null    float64
#  6   appCat.finance        444 non-null    float64
#  7   appCat.game           444 non-null    float64
#  8   appCat.office         444 non-null    float64
#  9   appCat.other          444 non-null    float64
#  10  appCat.social         444 non-null    float64
#  11  appCat.travel         444 non-null    float64
#  12  appCat.unknown        444 non-null    float64
#  13  appCat.utilities      444 non-null    float64
# ...

# %%
pivot.corr()
# Out:
# variable              activity  appCat.builtin  appCat.communication  \
# variable
# activity              1.000000        0.216405              0.391641
# appCat.builtin        0.216405        1.000000              0.202890
# appCat.communication  0.391641        0.202890              1.000000
# appCat.entertainment  0.259110        0.052743              0.304803
# appCat.finance        0.181569        0.120895              0.179397
# appCat.game           0.162543        0.108861              0.083395
# appCat.office         0.363991        0.284054              0.185074
# appCat.other          0.416909        0.271130              0.495688
# appCat.social         0.241364        0.100868              0.357157
# appCat.travel         0.228359        0.062049              0.207698
# appCat.unknown        0.150789        0.377841              0.126126
# appCat.utilities      0.217006        0.059048              0.155179
# ...

# %% [markdown]
# ## TEST  FOR ASSIGNMENT

# %%
#Trying to just aggregate datat on the daily basis, since just one user reports the mood per day -->
# It is a bit weird, but i guess that is how it is hahah
test1 = pd.DataFrame(df_data.groupby([pd.Grouper(key='time', freq='D'),'variable']).value.mean()).reset_index()
test1
# Out:
#            time            variable       value
# 0    2014-02-17                call    1.000000
# 1    2014-02-17                 sms    1.000000
# 2    2014-02-18                call    1.000000
# 3    2014-02-18                 sms    1.000000
# 4    2014-02-19                call    1.000000
# ...         ...                 ...         ...
# 1535 2014-06-08  circumplex.arousal   -1.500000
# 1536 2014-06-08  circumplex.valence    1.000000
# 1537 2014-06-08                mood    6.500000
# 1538 2014-06-08              screen  161.599714
# 1539 2014-06-09            activity    0.250000
#
# [1540 rows x 3 columns]

# %%
table_pivot = test1.pivot_table(index=['time'],
                            columns = 'variable', values='value', aggfunc='first',
                                #fill_value=0
                               )

# %%
table_pivot_test=table_pivot.dropna(subset=['mood'])

# %%
table_pivot_test
# Out:
# variable    activity  appCat.builtin  appCat.communication  \
# time
# 2014-02-26       NaN             NaN                   NaN
# 2014-02-27       NaN             NaN                   NaN
# 2014-03-04       NaN             NaN                   NaN
# 2014-03-05       NaN             NaN                   NaN
# 2014-03-06       NaN             NaN                   NaN
# ...              ...             ...                   ...
# 2014-06-04  0.046385        9.522432             56.443329
# 2014-06-05  0.152343       13.994216             25.914081
# 2014-06-06  0.189476        6.568736             38.884636
# 2014-06-07  0.081893      125.687450             27.257963
# 2014-06-08  0.079510       19.521611            187.757500
#
# variable    appCat.entertainment  appCat.finance  appCat.game  appCat.office  \
# time
# 2014-02-26                   NaN             NaN          NaN            NaN
# 2014-02-27                   NaN             NaN          NaN            NaN
# ...

# %%
table_pivot_test1=table_pivot_test.copy()
table_pivot_test1
# Out:
# variable    activity  appCat.builtin  appCat.communication  \
# time
# 2014-02-26       NaN             NaN                   NaN
# 2014-02-27       NaN             NaN                   NaN
# 2014-03-04       NaN             NaN                   NaN
# 2014-03-05       NaN             NaN                   NaN
# 2014-03-06       NaN             NaN                   NaN
# ...              ...             ...                   ...
# 2014-06-04  0.046385        9.522432             56.443329
# 2014-06-05  0.152343       13.994216             25.914081
# 2014-06-06  0.189476        6.568736             38.884636
# 2014-06-07  0.081893      125.687450             27.257963
# 2014-06-08  0.079510       19.521611            187.757500
#
# variable    appCat.entertainment  appCat.finance  appCat.game  appCat.office  \
# time
# 2014-02-26                   NaN             NaN          NaN            NaN
# 2014-02-27                   NaN             NaN          NaN            NaN
# ...

# %%
table_pivot_test1['sms'] = table_pivot_test1['sms'].fillna(0)

# %%
table_pivot_test1['call'] = table_pivot_test1['call'].fillna(0)

# %%
table_pivot_test1= table_pivot_test1.fillna(table_pivot_test1.median())

# %%
table_pivot_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 98 entries, 2014-02-26 to 2014-06-08
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   activity              83 non-null     float64
#  1   appCat.builtin        87 non-null     float64
#  2   appCat.communication  87 non-null     float64
#  3   appCat.entertainment  79 non-null     float64
#  4   appCat.finance        52 non-null     float64
#  5   appCat.game           50 non-null     float64
#  6   appCat.office         60 non-null     float64
#  7   appCat.other          87 non-null     float64
#  8   appCat.social         85 non-null     float64
#  9   appCat.travel         69 non-null     float64
#  10  appCat.unknown        66 non-null     float64
#  11  appCat.utilities      76 non-null     float64
#  12  appCat.weather        51 non-null     float64
#  13  call                  95 non-null     float64
# ...

# %%
table_pivot_test.describe()
# Out:
# variable   activity  appCat.builtin  appCat.communication  \
# count     83.000000       87.000000             87.000000
# mean       0.104681       18.411569             46.666239
# std        0.038328       14.400941             18.869914
# min        0.030704      -22.177944             25.914081
# 25%        0.078504       12.909238             39.366666
# 50%        0.105720       15.479508             42.825565
# 75%        0.125719       21.178007             48.568130
# max        0.230711      125.687450            187.757500
#
# variable  appCat.entertainment  appCat.finance  appCat.game  appCat.office  \
# count                79.000000       52.000000    50.000000      60.000000
# mean                 44.146602       21.620137   116.384918      32.892515
# std                  21.961435       10.483821    85.256887      52.706895
# min                   6.882740        3.504636     4.693000       4.292484
# ...

# %%
table_pivot_test1
# Out:
# variable    activity  appCat.builtin  appCat.communication  \
# time
# 2014-02-26  0.105720       15.479508             42.825565
# 2014-02-27  0.105720       15.479508             42.825565
# 2014-03-04  0.105720       15.479508             42.825565
# 2014-03-05  0.105720       15.479508             42.825565
# 2014-03-06  0.105720       15.479508             42.825565
# ...              ...             ...                   ...
# 2014-06-04  0.046385        9.522432             56.443329
# 2014-06-05  0.152343       13.994216             25.914081
# 2014-06-06  0.189476        6.568736             38.884636
# 2014-06-07  0.081893      125.687450             27.257963
# 2014-06-08  0.079510       19.521611            187.757500
#
# variable    appCat.entertainment  appCat.finance  appCat.game  appCat.office  \
# time
# 2014-02-26             37.174286       21.249192   110.320917      16.565747
# 2014-02-27             37.174286       21.249192   110.320917      16.565747
# ...

# %%
table_pivot_test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 98 entries, 2014-02-26 to 2014-06-08
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   activity              98 non-null     float64
#  1   appCat.builtin        98 non-null     float64
#  2   appCat.communication  98 non-null     float64
#  3   appCat.entertainment  98 non-null     float64
#  4   appCat.finance        98 non-null     float64
#  5   appCat.game           98 non-null     float64
#  6   appCat.office         98 non-null     float64
#  7   appCat.other          98 non-null     float64
#  8   appCat.social         98 non-null     float64
#  9   appCat.travel         98 non-null     float64
#  10  appCat.unknown        98 non-null     float64
#  11  appCat.utilities      98 non-null     float64
#  12  appCat.weather        98 non-null     float64
#  13  call                  98 non-null     float64
# ...

# %%
table_pivot_test1.corr()
# Out:
# variable              activity  appCat.builtin  appCat.communication  \
# variable
# activity              1.000000        0.086262             -0.206391
# appCat.builtin        0.086262        1.000000             -0.114819
# appCat.communication -0.206391       -0.114819              1.000000
# appCat.entertainment -0.329704       -0.100866             -0.100309
# appCat.finance       -0.033999       -0.166605              0.038791
# appCat.game          -0.002088        0.018873             -0.041822
# appCat.office         0.135836        0.142321             -0.068954
# appCat.other          0.141041       -0.055191             -0.110827
# appCat.social        -0.367466       -0.119053              0.363730
# appCat.travel         0.087996        0.012436             -0.036340
# appCat.unknown        0.067297       -0.031294             -0.026269
# appCat.utilities      0.084635       -0.128146             -0.069320
# ...

# %%
# Plotting the seaborn heatmap 
fig = plt.figure(figsize=[20,20])
sns.heatmap(table_pivot_test1.corr(), annot=True, cmap="Greens")
plt.show()
