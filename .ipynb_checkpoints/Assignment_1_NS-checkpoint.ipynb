# %% [markdown]
# ### Assignment points based on the research paper done by W. van Breda, J. Pastor, M. Hoogendoorn
#
# - The values are aggregated per day
# - Number of calls and SMS messages to the top 5 contacts are measured as normalized frequency values.
# - The duration of calls made to the top 5 contacts was measured, and the frequency and duration of the applications are measured as well
# - appCat.n and appCat.duration are attributes representing the number of uses and duration for application categories. These variables are normalized per day between all categories of their respective class
# - The following attributes are also included: the number of images taken (image.n), the average screen duration per screen-on moment (screen.duration) and the screen-on frequency (screen.n), which were all normalized within the participant.
# - average percentage of accelerometer data that is classified as “high” (accelerometer.high).
#
# #### --> imputation of missing values - means fill in the missing things with numbers!!!
# - The eMate EMA application prompts the user to rate their mood five times per day (at 09:00, 12:00, 15:00, 18:00 and 21:00)
# - In case the participants expressed their mood multiple times a day, an average was calculated for each day.
#
# #### Attribute Engineering
# - One attribute that was added concerns the weekday, which was calculated by using the already available data/time attribute.
# - Another two attributes were the sum of call request and/or SMS to the top 5 persons for each day, and the sum of application usage of applications belonging to the top 5 used applications each day.
#
# #### Missing value imputation
# - average everywhere just dropping in the mood variable --> the one we need to predict in the end
#
# #### Used metrics to evaluate the performance of the models
# - MSE
# - mean absolute error (MAE)
# - mean absolute percentage error (MAPE)
# - root mean square error (RMSE)

# %% [markdown]
# # Assignment 1 - Advanced

# %% [markdown]
# Task: Predict the average mood of the user on the next day based on the data we obtained from the user on the days before

# %% [markdown]
# ### Insert Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import pylab
import category_encoders as ce
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### Get data

# %%
#Loading the data
df_data = pd.read_csv('dataset_mood_smartphone.csv')

# %%
#Sorting values based on the id and time and reseting the index so we made dates callable.
df_data = df_data.sort_values(['id','time'])
df_data.reset_index(drop=True,inplace=True)
df_data.head()
# Out:
#    Unnamed: 0       id                     time variable  value
# 0      136471  AS14.01  2014-02-17 12:04:42.394     call    1.0
# 1      136472  AS14.01  2014-02-17 18:28:25.520     call    1.0
# 2      136473  AS14.01  2014-02-18 09:29:51.257     call    1.0
# 3      136474  AS14.01  2014-02-19 14:43:30.575     call    1.0
# 4      136475  AS14.01  2014-02-19 17:29:10.378     call    1.0

# %%
#Checking the count of the variables in the dataset on the basic df we got --> normal csv file
pd.DataFrame(df_data.variable.value_counts()).plot.bar(title="Histogram of Features", legend=None,figsize=(10,7));

# %%
#Found it on the internet but super useful for EDA = Exploratory data analysis we need to do.
#Although this data set without pivoting not really useful to use the profile report function.
#https://towardsdatascience.com/exploratory-data-analysis-with-pandas-profiling-de3aae2ddff3
from pandas_profiling import ProfileReport
profile = ProfileReport(df_data, title="Pandas Profiling Report")
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-04-17 23:04:01.345930&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ## PRE-PROCESSING THE DATA

# %% [markdown]
# _____________________________________________________________________________________________________________

# %%
#Groupping the data by the min and max value of TIME and sorted on the min value of time given 
#--> id is used as an index
df_data.groupby('id')['time'].agg(['min', 'max']).sort_values(['min'])
# Out:
#                              min                      max
# id
# AS14.02  2014-02-17 07:00:52.197  2014-04-25 21:00:00.000
# AS14.06  2014-02-17 07:12:13.631  2014-05-08 09:00:00.000
# AS14.14  2014-02-17 07:49:19.635  2014-05-05 15:00:00.000
# AS14.17  2014-02-17 08:57:16.313  2014-05-05 15:00:00.000
# AS14.19  2014-02-17 08:58:58.471  2014-05-05 18:00:00.000
# AS14.28  2014-02-17 09:48:49.536  2014-05-08 13:37:16.006
# AS14.20  2014-02-17 09:52:02.075  2014-05-05 13:00:00.000
# AS14.26  2014-02-17 09:58:59.766  2014-05-30 21:00:00.000
# AS14.29  2014-02-17 10:42:05.661  2014-05-15 12:00:00.000
# AS14.09  2014-02-17 10:47:29.664  2014-05-05 12:00:00.000
# AS14.16  2014-02-17 11:18:33.513  2014-05-05 15:00:00.000
# AS14.25  2014-02-17 11:50:46.069  2014-05-08 14:00:00.000
# AS14.01  2014-02-17 12:04:42.394  2014-05-05 10:00:00.000
# AS14.08  2014-02-17 12:51:38.029  2014-05-05 15:00:00.000
# AS14.23  2014-02-17 14:31:48.654  2014-05-04 02:52:14.772
# ...

# %%
#Groupping the data on varibales, again with min and max value
#Data for apppCat.builtin has value of -82798.871 --> could be an outlier ??
#Should we normalize/standardize some data points?
df_data.groupby(['variable'])['value'].agg(['min', 'max'])
# Out:
#                             min        max
# variable
# activity                  0.000      1.000
# appCat.builtin       -82798.871  33960.246
# appCat.communication      0.006   9830.777
# appCat.entertainment     -0.011  32148.677
# appCat.finance            0.131    355.513
# appCat.game               1.003   5491.793
# appCat.office             0.003  32708.818
# appCat.other              0.014   3892.038
# appCat.social             0.094  30000.906
# appCat.travel             0.080  10452.615
# appCat.unknown            0.111   2239.937
# appCat.utilities          0.246   1802.649
# appCat.weather            1.003    344.863
# call                      1.000      1.000
# circumplex.arousal       -2.000      2.000
# circumplex.valence       -2.000      2.000
# mood                      1.000     10.000
# screen                    0.035   9867.007
# sms                       1.000      1.000

# %%
df_data['variable'].unique()
# Out:
# array(['call', 'sms', 'mood', 'circumplex.arousal', 'circumplex.valence',
#        'activity', 'appCat.other', 'appCat.builtin',
#        'appCat.communication', 'appCat.entertainment', 'appCat.social',
#        'screen', 'appCat.utilities', 'appCat.unknown', 'appCat.finance',
#        'appCat.travel', 'appCat.office', 'appCat.weather', 'appCat.game'],
#       dtype=object)

# %%
#Detection of the "outlier" --> not sure if it is --> but most data pooints is at around 0-2.000
df_data[(df_data['variable'] == 'appCat.builtin')&(df_data['value'] < -80000)]
# Out:
#         Unnamed: 0       id                     time        variable  \
# 100194      622771  AS14.07  2014-04-30 14:18:06.200  appCat.builtin
#
#             value
# 100194 -82798.871

# %%
df_data.drop(100194, axis=0, inplace=True)

# %%
#Detection of the "outlier" --> not sure if it is --> but most data pooints is at around 0-3.000
df_data[(df_data['variable'] == 'appCat.entertainment')&(df_data['value'] < -0.01)]
# Out:
#        Unnamed: 0       id                     time              variable  \
# 27778      484694  AS14.02  2014-03-26 21:18:45.144  appCat.entertainment
#
#        value
# 27778 -0.011

# %%
df_data.drop(27778, axis=0, inplace=True)

# %% [markdown]
# The circumplex model of emotion was developed by James Russell. This model suggests that emotions are distributed in a two-dimensional circular space, containing arousal and valence dimensions.
# Arousal represents the vertical axis and valence represents the horizontal axis, while the center of the circle represents a neutral valence and a medium level of arousal. In this model, emotional states can be represented at any level of valence and arousal, or at a neutral level of one or both of these factors.
#
# --> source: Wikipedia haha

# %%
#Checking if all the time when mood is reported, also circumplex and arousal are reported
#As seen down it is the case --> which means those variables are highly correlated
#May consider to drop in case of bias analysis if we use them later ? not sure about this
targets_num_df = df_data[df_data['variable'].isin(['mood', 'circumplex.valence', 'circumplex.arousal'])].\
    groupby(['id', 'time'])['variable'].unique()

# %%
targets_num_df
# Out:
# id       time
# AS14.01  2014-02-26 13:00:00.000    [mood, circumplex.arousal, circumplex.valence]
#          2014-02-26 15:00:00.000    [mood, circumplex.arousal, circumplex.valence]
#          2014-02-26 18:00:00.000    [mood, circumplex.arousal, circumplex.valence]
#          2014-02-26 21:00:00.000    [mood, circumplex.arousal, circumplex.valence]
#          2014-02-27 09:00:00.000    [mood, circumplex.arousal, circumplex.valence]
#                                                          ...
# AS14.33  2014-05-30 09:00:00.000    [mood, circumplex.arousal, circumplex.valence]
#          2014-05-30 13:00:00.000    [mood, circumplex.arousal, circumplex.valence]
#          2014-05-30 19:00:00.000    [mood, circumplex.arousal, circumplex.valence]
#          2014-05-30 20:00:00.000    [mood, circumplex.arousal, circumplex.valence]
#          2014-05-31 12:00:00.000    [mood, circumplex.arousal, circumplex.valence]
# Name: variable, Length: 5628, dtype: object

# %% [markdown]
# As we can see in the first two columns --> mood is reported more than once per day --> which suggested, that either we take the mean of all the moods user reported or we use just the last/first reported value. The decision need to be made, but i think either way it does not make a lot of difference, it is just one thing we need to put good argument why we used what we used!

# %%
df_data
# Out:
#         Unnamed: 0       id                     time            variable  \
# 0           136471  AS14.01  2014-02-17 12:04:42.394                call
# 1           136472  AS14.01  2014-02-17 18:28:25.520                call
# 2           136473  AS14.01  2014-02-18 09:29:51.257                call
# 3           136474  AS14.01  2014-02-19 14:43:30.575                call
# 4           136475  AS14.01  2014-02-19 17:29:10.378                call
# ...            ...      ...                      ...                 ...
# 376907      233404  AS14.33  2014-05-30 22:32:14.240      appCat.builtin
# 376908      233405  AS14.33  2014-05-30 22:32:15.246      appCat.builtin
# 376909        5641  AS14.33  2014-05-31 12:00:00.000                mood
# 376910       11284  AS14.33  2014-05-31 12:00:00.000  circumplex.arousal
# 376911       16927  AS14.33  2014-05-31 12:00:00.000  circumplex.valence
#
#         value
# 0       1.000
# 1       1.000
# 2       1.000
# 3       1.000
# ...

# %%
#With this function we can only use the last or first value, or just drop everything that is duplicated 
#--> i used now LAST variable, but not really sure if this makes sense 
#--> would make more sense to use the mean right?

df= df_data.drop_duplicates(['id', 'time', 'variable'], keep='last')

# %%
df
# Out:
#         Unnamed: 0       id                     time            variable  \
# 0           136471  AS14.01  2014-02-17 12:04:42.394                call
# 1           136472  AS14.01  2014-02-17 18:28:25.520                call
# 2           136473  AS14.01  2014-02-18 09:29:51.257                call
# 3           136474  AS14.01  2014-02-19 14:43:30.575                call
# 4           136475  AS14.01  2014-02-19 17:29:10.378                call
# ...            ...      ...                      ...                 ...
# 376907      233404  AS14.33  2014-05-30 22:32:14.240      appCat.builtin
# 376908      233405  AS14.33  2014-05-30 22:32:15.246      appCat.builtin
# 376909        5641  AS14.33  2014-05-31 12:00:00.000                mood
# 376910       11284  AS14.33  2014-05-31 12:00:00.000  circumplex.arousal
# 376911       16927  AS14.33  2014-05-31 12:00:00.000  circumplex.valence
#
#         value
# 0       1.000
# 1       1.000
# 2       1.000
# 3       1.000
# ...

# %%
df[(df['id'] == 'AS14.01')].sort_values(['time', 'variable'])
# Out:
#        Unnamed: 0       id                     time        variable   value
# 0          136471  AS14.01  2014-02-17 12:04:42.394            call   1.000
# 1          136472  AS14.01  2014-02-17 18:28:25.520            call   1.000
# 2          136473  AS14.01  2014-02-18 09:29:51.257            call   1.000
# 3          136474  AS14.01  2014-02-19 14:43:30.575            call   1.000
# 4          136475  AS14.01  2014-02-19 17:29:10.378            call   1.000
# ...           ...      ...                      ...             ...     ...
# 21994      146441  AS14.01  2014-05-05 09:41:40.795  appCat.builtin   3.423
# 21995      146451  AS14.01  2014-05-05 09:41:44.243  appCat.builtin   1.047
# 21996      146462  AS14.01  2014-05-05 09:41:45.292  appCat.builtin  12.049
# 21997      146472  AS14.01  2014-05-05 09:41:57.378  appCat.builtin   3.033
# 21998       17983  AS14.01  2014-05-05 10:00:00.000        activity   0.000
#
# [21994 rows x 5 columns]

# %%
df.time = pd.to_datetime(df.time, format='%Y-%m-%d %H:%M:%S.%f')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 376867 entries, 0 to 376911
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  376867 non-null  int64
#  1   id          376867 non-null  object
#  2   time        376867 non-null  datetime64[ns]
#  3   variable    376867 non-null  object
#  4   value       376666 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 17.3+ MB
# /Users/nezasmid/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
pd.pivot(df, columns=['variable'], values=['value'], index=['id', 'time']).head()
# Out:
#                                    value                                      \
# variable                        activity appCat.builtin appCat.communication
# id      time
# AS14.01 2014-02-17 12:04:42.394      NaN            NaN                  NaN
#         2014-02-17 18:28:25.520      NaN            NaN                  NaN
#         2014-02-18 09:29:51.257      NaN            NaN                  NaN
#         2014-02-19 14:43:30.575      NaN            NaN                  NaN
#         2014-02-19 17:29:10.378      NaN            NaN                  NaN
#
#                                                                      \
# variable                        appCat.entertainment appCat.finance
# id      time
# AS14.01 2014-02-17 12:04:42.394                  NaN            NaN
#         2014-02-17 18:28:25.520                  NaN            NaN
#         2014-02-18 09:29:51.257                  NaN            NaN
# ...

# %% [markdown]
# _____________________________________________________________________________________________________________

# %%
df['time'] = df['time'].dt.floor('D')
df.head()
# Out:
# <ipython-input-21-7d1ec8063a36>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['time'] = df['time'].dt.floor('D')
#    Unnamed: 0       id       time variable  value
# 0      136471  AS14.01 2014-02-17     call    1.0
# 1      136472  AS14.01 2014-02-17     call    1.0
# 2      136473  AS14.01 2014-02-18     call    1.0
# 3      136474  AS14.01 2014-02-19     call    1.0
# 4      136475  AS14.01 2014-02-19     call    1.0

# %%
pivoted_df = pd.pivot_table(df, values = 'value', index=['id','time'], columns = 'variable', aggfunc='mean',).reset_index()
pivoted_df = pivoted_df[~pivoted_df['mood'].isna()]
pivoted_df.columns.name = None

# according to the previous finding
pivoted_df.drop(['circumplex.arousal', 'circumplex.valence'], axis=1, inplace=True)

print('pivoted_df.shape', pivoted_df.shape)
pivoted_df.head()
# Out:
# pivoted_df.shape (1268, 19)
#          id       time  activity  appCat.builtin  appCat.communication  \
# 7   AS14.01 2014-02-26       NaN             NaN                   NaN
# 8   AS14.01 2014-02-27       NaN             NaN                   NaN
# 26  AS14.01 2014-03-21  0.134050       14.269173             55.095526
# 27  AS14.01 2014-03-22  0.236880        7.781160             51.697063
# 28  AS14.01 2014-03-23  0.142741       12.134396             53.442031
#
#     appCat.entertainment  appCat.finance  appCat.game  appCat.office  \
# 7                    NaN             NaN          NaN            NaN
# 8                    NaN             NaN          NaN            NaN
# 26             53.024000        6.193000          NaN         57.402
# 27             46.662000        7.025333          NaN            NaN
# 28             31.448667       10.850750          NaN            NaN
#
#     appCat.other  appCat.social  appCat.travel  appCat.unknown  \
# ...

# %%
pivoted_df.fillna(0, inplace=True)

# %%
pivoted_df
# Out:
#            id       time  activity  appCat.builtin  appCat.communication  \
# 7     AS14.01 2014-02-26  0.000000        0.000000              0.000000
# 8     AS14.01 2014-02-27  0.000000        0.000000              0.000000
# 26    AS14.01 2014-03-21  0.134050       14.269173             55.095526
# 27    AS14.01 2014-03-22  0.236880        7.781160             51.697063
# 28    AS14.01 2014-03-23  0.142741       12.134396             53.442031
# ...       ...        ...       ...             ...                   ...
# 1968  AS14.33 2014-05-27  0.012704        8.545776             59.382943
# 1969  AS14.33 2014-05-28  0.103301        9.590398             37.238750
# 1970  AS14.33 2014-05-29  0.169354        6.452161             54.388125
# 1971  AS14.33 2014-05-30  0.192901       14.776845             46.412278
# 1972  AS14.33 2014-05-31  0.000000        0.000000              0.000000
#
#       appCat.entertainment  appCat.finance  appCat.game  appCat.office  \
# ...

# %%
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('tab20')

num=1
f= plt.figure(figsize=(40,20))
for var in list(pivoted_df.columns.array):
    ax = f.add_subplot(5,4,num)
    a = np.asarray(pivoted_df[var].dropna())
    ax.hist(a, bins=70, color=palette(num))
    ax.set_title(var)
    num+=1

# %%
pivoted_df.describe()
# Out:
#           activity  appCat.builtin  appCat.communication  \
# count  1268.000000     1268.000000           1268.000000
# mean      0.108037       23.721878             41.059778
# std       0.098451       73.694224             37.609296
# min       0.000000        0.000000              0.000000
# 25%       0.039177        6.825718             23.439992
# 50%       0.087447       11.460637             36.354452
# 75%       0.140809       19.712886             50.695796
# max       0.549430     1399.054714            522.718000
#
#        appCat.entertainment  appCat.finance  appCat.game  appCat.office  \
# count           1268.000000     1268.000000  1268.000000    1268.000000
# mean              61.773177        4.187153    23.384565       8.997908
# std              128.662757       13.759092   114.194331      51.682849
# min                0.000000        0.000000     0.000000       0.000000
# 25%                0.000000        0.000000     0.000000       0.000000
# ...

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------

# %%
df_data1=df_data.copy()
df_data1.time = pd.to_datetime(df_data.time, format='%Y-%m-%d %H:%M:%S.%f')

# %%
test = pd.DataFrame(df_data1.groupby([pd.Grouper(key='time', freq='D'),'variable','id']).value.mean())

#test= pd.DataFrame(df_data.groupby(['id', pd.Grouper(key='time', freq='D')])['variable'].mean())

# %%
table = test.pivot_table(index=['id','time'], columns = 'variable', values='value', aggfunc='first')

# %%
table=table.reset_index()

# %%
table= table.dropna(subset=['mood'])

# %%
columns_zero=['activity','appCat.builtin','appCat.communication',
      'appCat.entertainment','appCat.finance','appCat.game',
      'appCat.office','appCat.other','appCat.social','appCat.travel',
      'appCat.unknown','appCat.utilities','appCat.weather',
      'call','screen','sms']
table[columns_zero]=table[columns_zero].fillna(0)
# table=table.fillna(method='ffill')
# table=table.fillna(method='bfill')
table
# Out:
# variable       id       time  activity  appCat.builtin  appCat.communication  \
# 7         AS14.01 2014-02-26  0.000000        0.000000              0.000000
# 8         AS14.01 2014-02-27  0.000000        0.000000              0.000000
# 26        AS14.01 2014-03-21  0.134050       14.269173             55.095526
# 27        AS14.01 2014-03-22  0.236880        7.781160             51.697063
# 28        AS14.01 2014-03-23  0.142741       12.134396             53.442031
# ...           ...        ...       ...             ...                   ...
# 1968      AS14.33 2014-05-27  0.012704        8.545776             59.382943
# 1969      AS14.33 2014-05-28  0.103301        9.590398             37.238750
# 1970      AS14.33 2014-05-29  0.169354        6.452161             54.388125
# 1971      AS14.33 2014-05-30  0.192901       14.776845             46.412278
# 1972      AS14.33 2014-05-31  0.000000        0.000000              0.000000
#
# ...

# %%
table=table.reset_index()
table['time'] = pd.to_datetime(table['time'])

# %%
table['timedelta']=table['time']-table['time'].shift()
table.loc[table['timedelta'].isna(), 'timedelta']= pd.Timedelta(0)
table['timedelta']/= pd.Timedelta(1,'d')
table
# Out:
# variable  index       id       time  activity  appCat.builtin  \
# 0             7  AS14.01 2014-02-26  0.000000        0.000000
# 1             8  AS14.01 2014-02-27  0.000000        0.000000
# 2            26  AS14.01 2014-03-21  0.134050       14.269173
# 3            27  AS14.01 2014-03-22  0.236880        7.781160
# 4            28  AS14.01 2014-03-23  0.142741       12.134396
# ...         ...      ...        ...       ...             ...
# 1263       1968  AS14.33 2014-05-27  0.012704        8.545776
# 1264       1969  AS14.33 2014-05-28  0.103301        9.590398
# 1265       1970  AS14.33 2014-05-29  0.169354        6.452161
# 1266       1971  AS14.33 2014-05-30  0.192901       14.776845
# 1267       1972  AS14.33 2014-05-31  0.000000        0.000000
#
# variable  appCat.communication  appCat.entertainment  appCat.finance  \
# 0                     0.000000              0.000000        0.000000
# 1                     0.000000              0.000000        0.000000
# ...

# %% [markdown]
# ### Feature engineering

# %%
pivoted_table=table.copy()

# %%
#Adding features --> feature engineering --> adding different apps into cattegories
pivoted_table['appCat.work'] = pivoted_table[['appCat.office', 'appCat.finance','appCat.builtin']].sum(axis=1, skipna=True)
pivoted_table['appCat.free_time'] = pivoted_table[['appCat.communication','appCat.game','appCat.entertainment','appCat.social']].sum(axis=1, skipna=True)
pivoted_table['appCat.others'] = pivoted_table[['appCat.travel','appCat.utilities','appCat.weather','appCat.other','appCat.unknown']].sum(axis=1, skipna=True)
column_names = ['appCat.builtin','appCat.communication','appCat.entertainment','appCat.finance','appCat.game','appCat.office','appCat.other','appCat.social','appCat.travel','appCat.unknown','appCat.utilities','appCat.weather']
pivoted_table = pivoted_table.drop(columns=column_names, axis=1)

# %%
pivoted_table
# Out:
# variable  index       id       time  activity  call  circumplex.arousal  \
# 0             7  AS14.01 2014-02-26  0.000000   1.0           -0.250000
# 1             8  AS14.01 2014-02-27  0.000000   0.0            0.000000
# 2            26  AS14.01 2014-03-21  0.134050   1.0            0.200000
# 3            27  AS14.01 2014-03-22  0.236880   1.0            0.600000
# 4            28  AS14.01 2014-03-23  0.142741   0.0            0.200000
# ...         ...      ...        ...       ...   ...                 ...
# 1263       1968  AS14.33 2014-05-27  0.012704   1.0           -0.600000
# 1264       1969  AS14.33 2014-05-28  0.103301   1.0            0.000000
# 1265       1970  AS14.33 2014-05-29  0.169354   1.0           -1.333333
# 1266       1971  AS14.33 2014-05-30  0.192901   1.0           -0.800000
# 1267       1972  AS14.33 2014-05-31  0.000000   0.0           -2.000000
#
# variable  circumplex.valence      mood      screen  sms  timedelta  \
# ...

# %%
new_variables = ['activity','call','circumplex.arousal','circumplex.valence','mood',
                 'screen','sms','timedelta','appCat.work','appCat.free_time', 'appCat.others']
ids = pivoted_table.id.unique()

# %%
pivoted_table.reset_index(inplace=True, drop=True)
pivoted_table.set_index(['id','time'],inplace=True,drop=True)

# %%
pivoted_table
# Out:
# variable            index  activity  call  circumplex.arousal  \
# id      time
# AS14.01 2014-02-26      7  0.000000   1.0           -0.250000
#         2014-02-27      8  0.000000   0.0            0.000000
#         2014-03-21     26  0.134050   1.0            0.200000
#         2014-03-22     27  0.236880   1.0            0.600000
#         2014-03-23     28  0.142741   0.0            0.200000
# ...                   ...       ...   ...                 ...
# AS14.33 2014-05-27   1968  0.012704   1.0           -0.600000
#         2014-05-28   1969  0.103301   1.0            0.000000
#         2014-05-29   1970  0.169354   1.0           -1.333333
#         2014-05-30   1971  0.192901   1.0           -0.800000
#         2014-05-31   1972  0.000000   0.0           -2.000000
#
# variable            circumplex.valence      mood      screen  sms  timedelta  \
# id      time
# AS14.01 2014-02-26            0.750000  6.250000    0.000000  1.0        0.0
# ...

# %%
for var in new_variables:
        pivoted_table[str(var)+'_1lagvalues'] = np.nan
        pivoted_table[str(var)+'_2lagvalues'] = np.nan
        pivoted_table[str(var)+'_3lagvalues'] = np.nan
        

for i in ids:
    for var in new_variables:
        a = pivoted_table.loc[i].index
        for j in np.arange(3,len(a)):
            pivoted_table.loc[i,str(var)+'_1lagvalues'][a[j]] = pivoted_table.loc[i,var][a[j-1]]
            pivoted_table.loc[i,str(var)+'_2lagvalues'][a[j]] = pivoted_table.loc[i,var][a[j-2]]
            pivoted_table.loc[i,str(var)+'_3lagvalues'][a[j]] = pivoted_table.loc[i,var][a[j-3]]
# Out:
# /Users/nezasmid/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
pivoted_table
# Out:
# variable            index  activity  call  circumplex.arousal  \
# id      time
# AS14.01 2014-02-26      7  0.000000   1.0           -0.250000
#         2014-02-27      8  0.000000   0.0            0.000000
#         2014-03-21     26  0.134050   1.0            0.200000
#         2014-03-22     27  0.236880   1.0            0.600000
#         2014-03-23     28  0.142741   0.0            0.200000
# ...                   ...       ...   ...                 ...
# AS14.33 2014-05-27   1968  0.012704   1.0           -0.600000
#         2014-05-28   1969  0.103301   1.0            0.000000
#         2014-05-29   1970  0.169354   1.0           -1.333333
#         2014-05-30   1971  0.192901   1.0           -0.800000
#         2014-05-31   1972  0.000000   0.0           -2.000000
#
# variable            circumplex.valence      mood      screen  sms  timedelta  \
# id      time
# AS14.01 2014-02-26            0.750000  6.250000    0.000000  1.0        0.0
# ...

# %%
df_nontemporal=pivoted_table.dropna()
df_nontemporal=df_nontemporal.drop(columns=['timedelta_3lagvalues','timedelta_2lagvalues',
                                            'timedelta_1lagvalues','index'])
df_nontemporal
# Out:
# variable            activity  call  circumplex.arousal  circumplex.valence  \
# id      time
# AS14.01 2014-03-22  0.236880   1.0            0.600000                 0.5
#         2014-03-23  0.142741   0.0            0.200000                 0.8
#         2014-03-24  0.078961   1.0            0.800000                 0.0
#         2014-03-25  0.098374   0.0            0.500000                 0.5
#         2014-03-26  0.101308   0.0           -0.200000                 0.6
# ...                      ...   ...                 ...                 ...
# AS14.33 2014-05-27  0.012704   1.0           -0.600000                 0.4
#         2014-05-28  0.103301   1.0            0.000000                 1.2
#         2014-05-29  0.169354   1.0           -1.333333                 1.0
#         2014-05-30  0.192901   1.0           -0.800000                -0.4
#         2014-05-31  0.000000   0.0           -2.000000                 1.0
#
# ...

# %%
df_nontemporal.to_csv('df_nontemporal.csv')

# %%
df_nontemporal.describe()
# Out:
# variable     activity         call  circumplex.arousal  circumplex.valence  \
# count     1181.000000  1181.000000         1181.000000         1181.000000
# mean         0.110573     0.577477           -0.101087            0.686749
# std          0.098973     0.494170            0.665244            0.428766
# min          0.000000     0.000000           -2.000000           -1.250000
# 25%          0.042063     0.000000           -0.600000            0.400000
# 50%          0.089692     1.000000            0.000000            0.800000
# 75%          0.141319     1.000000            0.400000            1.000000
# max          0.549430     1.000000            2.000000            2.000000
#
# variable         mood       screen          sms    timedelta  appCat.work  \
# count     1181.000000  1181.000000  1181.000000  1181.000000  1181.000000
# mean         6.984857    77.045733     0.329382     1.026249    37.640788
# ...

# %%
df_nontemporal_option1=df_nontemporal.copy()
df_nontemporal_option1.reset_index(inplace=True)
df_nontemporal_option1
# Out:
# variable       id       time  activity  call  circumplex.arousal  \
# 0         AS14.01 2014-03-22  0.236880   1.0            0.600000
# 1         AS14.01 2014-03-23  0.142741   0.0            0.200000
# 2         AS14.01 2014-03-24  0.078961   1.0            0.800000
# 3         AS14.01 2014-03-25  0.098374   0.0            0.500000
# 4         AS14.01 2014-03-26  0.101308   0.0           -0.200000
# ...           ...        ...       ...   ...                 ...
# 1176      AS14.33 2014-05-27  0.012704   1.0           -0.600000
# 1177      AS14.33 2014-05-28  0.103301   1.0            0.000000
# 1178      AS14.33 2014-05-29  0.169354   1.0           -1.333333
# 1179      AS14.33 2014-05-30  0.192901   1.0           -0.800000
# 1180      AS14.33 2014-05-31  0.000000   0.0           -2.000000
#
# variable  circumplex.valence  mood      screen  sms  timedelta  ...  \
# 0                        0.5  6.40   47.613651  1.0        1.0  ...
# ...

# %%
enc = ce.OneHotEncoder(cols=['id'], 
                       use_cat_names=True)
df_nontemporal_option1 = enc.fit_transform(df_nontemporal_option1)
#df_nontemporal_option1.set_index(['time'],inplace=True,drop=True)

# %%
df_nontemporal_option1.set_index(['time'], inplace=True)

# %% [markdown]
# ### Machine learning models

# %%
target=df_nontemporal['mood']
database=df_nontemporal.drop(columns='mood')

target_1=df_nontemporal_option1['mood']
database_1=df_nontemporal_option1.drop(columns='mood')

x_train, x_test, y_train, y_test = train_test_split(database, target, test_size = 0.2, random_state = 32)
d_train, d_test, t_train, t_test = train_test_split(database_1, target_1, test_size = 0.2, random_state = 32)

# %% [markdown]
# #### SVM model

# %%
# Building a Support Vector Machine on train data
svr_model = SVR(C=1, kernel='rbf', gamma= 0.0001)
svr_model.fit(x_train, y_train)

y_pred=svr_model.predict(x_test)
  
prediction = svr_model .predict(x_test)
# check the accuracy on the training set
print(svr_model.score(x_train, y_train))
print(svr_model.score(x_test, y_test))
# Out:
# 0.7856082725967157
# -0.004780418426570288

# %%
svr_model = SVR(C=1, kernel='rbf', gamma= 0.0001)
svr_model.fit(d_train, t_train)

y_pred1=svr_model.predict(d_test)
  
prediction = svr_model .predict(d_test)
# check the accuracy on the training set
print(svr_model.score(d_train, t_train))
print(svr_model.score(d_test, t_test))
# Out:
# 0.78563498523469
# -0.004749987409197631

# %%
#hyper parameter tuning with a grid search 
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}
 
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
 
# fitting the model for grid search
grid.fit(x_train, y_train)
grid.fit(d_train,t_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV 2/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV 3/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV 4/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV 5/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.1s
# [CV 1/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 3/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 4/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 5/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 1/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.1s
# ...

# %%
# print best parameter after tuning
print(grid.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# SVR(C=100, gamma=0.001)

# %%
MSE=mean_squared_error(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MAPE=mean_absolute_percentage_error(y_test,y_pred)
print(f'MSE is {MSE}')
print(f'MAE is {MAE}')
print(f'MAPE is {MAPE}')
# Out:
# MSE is 0.5370158693359944
# MAE is 0.5323315695636527
# MAPE is 0.08110686532864816

# %% [markdown]
# ### RANDOM FOREST REGRESSION

# %%
# create regressor object
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
 
# fit the regressor with x and y data
regressor.fit(x_test, y_test) 


#predict
y_pred_rf=regressor.predict(x_test)

# %%
MSE_rf=mean_squared_error(y_test,y_pred_rf)
MAE_rf=mean_absolute_error(y_test,y_pred_rf)
MAPE_rf=mean_absolute_percentage_error(y_test,y_pred_rf)
print(f'MSE is {MSE_rf}')
print(f'MAE is {MAE_rf}')
print(f'MAPE is {MAPE_rf}')
# Out:
# MSE is 0.03775359481950307
# MAE is 0.1466251758087203
# MAPE is 0.022037433232815748

# %%
# param_grid = {
#     'bootstrap': [True],
#     'max_depth': [40, 60, 80, 100],
#     'max_features': ['auto'],
#     'min_samples_leaf': [1, 4],
#     'min_samples_split': [2, 4],
#     'n_estimators': [200, 500, 1000]
# }

# # Instantiate the grid search model
# rf_grid = GridSearchCV(estimator = RandomForestRegressor(random_state=32), param_grid = param_grid, 
#                           cv = 5, n_jobs = -1, verbose = 10)

# rf_grid.fit(x_train, y_train.values.ravel())
# print(rf_grid.best_params_)

# %%
#Feature importance
feature_importances = pd.DataFrame(regressor.feature_importances_,
                                   index = x_train.columns,
                                   columns=['importance']).sort_values('importance',ascending=False)

fig = plt.figure(figsize=(20,10))
plt.barh(feature_importances.index,feature_importances.importance)
# If you want to define your own labels,
# change indices to a list of labels on the following line.
#plt.yticks(range(X.shape[1]), indices)
#plt.ylim([-1, X.shape[1]])
plt.show()
fig.savefig('rf_importance.pdf')
# Out:
# <ipython-input-156-7bac1bc8bdf6>:12: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## BENCHMARK MODEl = stupid model

# %% [markdown]
# This is not normal --> i think the result are somehow coruppted, since i did not drop the mood NaNs, but i backward, forward filled them. Which kinda does not makes sense --> but our RF performanc is soo good so i don't want to change ahhaha
#
# - RF results: MSE is 0.024084648783347946, MAE is 0.10783289357959576, MAPE is 0.015866998019726176
# - Benchmark results: MSE is 0.3896516032417195, MAE is 0.3737226920366455, MAPE is 0.055961318637306884
# - SVM results: MSE is 0.48170262412955733, MAE is 0.5240509462969382, MAPE is 0.07832137201158626
# - Temporal results: WE STILL NEED THEM!!!

# %%
y_true=df_nontemporal['mood']
y_pred_bm=df_nontemporal['mood_1lagvalues']
print(y_true)
print(y_pred_bm)
# Out:
# id       time
# AS14.01  2014-03-22    6.40
#          2014-03-23    6.80
#          2014-03-24    6.00
#          2014-03-25    6.75
#          2014-03-26    6.60
#                        ...
# AS14.33  2014-05-27    6.20
#          2014-05-28    8.20
#          2014-05-29    7.00
#          2014-05-30    6.80
#          2014-05-31    7.00
# Name: mood, Length: 1181, dtype: float64
# id       time
# AS14.01  2014-03-22    6.20
#          2014-03-23    6.40
#          2014-03-24    6.80
#          2014-03-25    6.00
#          2014-03-26    6.75
#                        ...
# AS14.33  2014-05-27    5.40
#          2014-05-28    6.20
#          2014-05-29    8.20
#          2014-05-30    7.00
#          2014-05-31    6.80
# Name: mood_1lagvalues, Length: 1181, dtype: float64

# %%
MSE_bm=mean_squared_error(y_true,y_pred_bm)
MAE_bm=mean_absolute_error(y_true,y_pred_bm)
MAPE_bm=mean_absolute_percentage_error(y_true,y_pred_bm)
print(f'MSE is {MSE_bm}')
print(f'MAE is {MAE_bm}')
print(f'MAPE is {MAPE_bm}')
# Out:
# MSE is 0.5669924263806566
# MAE is 0.548250070561671
# MAPE is 0.08229617635894583

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # TEMPORAL MODEL = ARIMA/RNN

# %% [markdown]
# Data for users need to be continious, so every day should be followed by the next day (if we have data for the 21/03/2014, we also need to have data for 22/03/2014,...). The more continious days we have, the better the predictions. I tried to understand one guys code from github how they did it but i did not really figured it out what they did.
#
# So my "interpretation of the temporal model is(would be idk haha):
# - First i use just the temporal data, so dropping everything that has value of 0.0 in the timedelta column
# - Use ARIMA/RNN just on one user, also do test/train split on each user
# - Save MSE, MAPE, MAE for every user, and then calculate the "AVERAGE" to get the MSE and others that can be compared to the MSE and stuff we got for ML models

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Masking, Embedding

# %%
df_temporal= df_nontemporal.copy()

# %%
df_temporal.drop(df_temporal.loc[df_temporal['timedelta']==0].index, inplace=True)

# %%
df_temporal.drop(df_temporal.loc[df_temporal['timedelta']==2].index, inplace=True)
df_temporal.drop(df_temporal.loc[df_temporal['timedelta']==3].index, inplace=True)
df_temporal.drop(df_temporal.loc[df_temporal['timedelta']==7].index, inplace=True)

# %%
df_temporal['timedelta'].unique()
# Out:
# array([1.])

# %%
df_temporal['timedelta'].isna().sum()
# Out:
# 0

# %%
df_temporal=df_temporal.reset_index()

# %%
df_temporal_1= df_temporal[(df_temporal['id'] == 'AS14.01')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)
df_temporal_2 = df_temporal[(df_temporal['id'] == 'AS14.02')]
database2=df_temporal_2['mood']
target2=df_temporal_2.drop(subset='mood')
x_train2, x_test2, y_train2, y_test2 = train_test_split(database2, 
                                                        target2, test_size = 0.2, random_state = 32)

df_temporal_3 = df_temporal[(df_temporal['id'] == 'AS14.03')]
database3=df_temporal_1['mood']
target3=df_temporal_1.drop(subset='mood')
x_train3, x_test3, y_train3, y_test3 = train_test_split(database3, 
                                                        target3, test_size = 0.2, random_state = 32)

df_temporal_4 = df_temporal[(df_temporal['id'] == 'AS14.05')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_5 = df_temporal[(df_temporal['id'] == 'AS14.06')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_6 = df_temporal[(df_temporal['id'] == 'AS14.07')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_7 = df_temporal[(df_temporal['id'] == 'AS14.08')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_8 = df_temporal[(df_temporal['id'] == 'AS14.09')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_9 = df_temporal[(df_temporal['id'] == 'AS14.12')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_10 = df_temporal[(df_temporal['id'] == 'AS14.13')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_11 = df_temporal[(df_temporal['id'] == 'AS14.14')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_12 = df_temporal[(df_temporal['id'] == 'AS14.15')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_13 = df_temporal[(df_temporal['id'] == 'AS14.16')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_14 = df_temporal[(df_temporal['id'] == 'AS14.17')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_15 = df_temporal[(df_temporal['id'] == 'AS14.19')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_16 = df_temporal[(df_temporal['id'] == 'AS14.20')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_17 = df_temporal[(df_temporal['id'] == 'AS14.23')]
database1=df_temporal_1['mood']
target1=df_temporal_1.drop(subset='mood')
x_train1, x_test1, y_train1, y_test1 = train_test_split(database1, 
                                                        target1, test_size = 0.2, random_state = 32)

df_temporal_18 = df_temporal[(df_temporal['id'] == 'AS14.24')]


df_temporal_19 = df_temporal[(df_temporal['id'] == 'AS14.25')]


df_temporal_20 = df_temporal[(df_temporal['id'] == 'AS14.26')]


df_temporal_21 = df_temporal[(df_temporal['id'] == 'AS14.27')]


df_temporal_22 = df_temporal[(df_temporal['id'] == 'AS14.28')]


df_temporal_23 = df_temporal[(df_temporal['id'] == 'AS14.29')]


df_temporal_24 = df_temporal[(df_temporal['id'] == 'AS14.30')]


df_temporal_25 = df_temporal[(df_temporal['id'] == 'AS14.31')]


df_temporal_26 = df_temporal[(df_temporal['id'] == 'AS14.32')]


df_temporal_27 = df_temporal[(df_temporal['id'] == 'AS14.33')]
